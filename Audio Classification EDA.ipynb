# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = 'D:\wave\sample.wav'
# Out:
# 'D:\\wave\\sample.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
# !dir
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 2ADE-3EF2
#
#  Directory of D:\wave
#
# 05/27/2023  08:52 PM    <DIR>          .
# 05/27/2023  08:36 PM    <DIR>          .ipynb_checkpoints
# 02/04/2020  06:41 PM           152,260 9031-3-3-0.wav
# 05/27/2023  08:52 PM             3,393 Audio Classification EDA.ipynb
# 05/27/2023  08:09 PM    <DIR>          fold1
# 05/27/2023  08:09 PM    <DIR>          fold10
# 05/27/2023  08:10 PM    <DIR>          fold2
# 05/27/2023  08:10 PM    <DIR>          fold3
# 05/27/2023  08:11 PM    <DIR>          fold4
# 05/27/2023  08:11 PM    <DIR>          fold5
# 05/27/2023  08:12 PM    <DIR>          fold6
# 05/27/2023  08:12 PM    <DIR>          fold7
# 05/27/2023  08:13 PM    <DIR>          fold8
# 05/27/2023  08:13 PM    <DIR>          fold9
# 02/04/2020  06:38 PM           494,104 UrbanSound8K.csv
#                3 File(s)        649,757 bytes
#               12 Dir(s)  108,077,547,520 bytes free

# %%
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([2416, 2388, 2349, ..., 2481, 2485, 2520], dtype=int16)

# %%
data
# Out:
# array([0.05424668, 0.0778658 , 0.06725552, ..., 0.07426675, 0.07336666,
#        0.08047701], dtype=float32)

# %%
import pandas as pd
metadata = pd.read_csv(r'D:\wave\UrbanSound8K.csv')

# %%
metadata
# Out:
#          slice_file_name    fsID       start         end  salience  fold
# 0       100032-3-0-0.wav  100032    0.000000    0.317551         1     5  \
# 1     100263-2-0-117.wav  100263   58.500000   62.500000         1     5
# 2     100263-2-0-121.wav  100263   60.500000   64.500000         1     5
# 3     100263-2-0-126.wav  100263   63.000000   67.000000         1     5
# 4     100263-2-0-137.wav  100263   68.500000   72.500000         1     5
# ...                  ...     ...         ...         ...       ...   ...
# 8727     99812-1-2-0.wav   99812  159.522205  163.522205         2     7
# 8728     99812-1-3-0.wav   99812  181.142431  183.284976         2     7
# 8729     99812-1-4-0.wav   99812  242.691902  246.197885         2     7
# 8730     99812-1-5-0.wav   99812  253.209850  255.741948         2     7
# 8731     99812-1-6-0.wav   99812  332.289233  334.821332         2     7
#
#       classID             class
# 0           3          dog_bark
# 1           2  children_playing
# 2           2  children_playing
# 3           2  children_playing
# 4           2  children_playing
# ...       ...               ...
# 8727        1          car_horn
# 8728        1          car_horn
# 8729        1          car_horn
# 8730        1          car_horn
# 8731        1          car_horn
#
# [8732 rows x 8 columns]

# %%
##check weather dataset is imbalanced
metadata['class'].value_counts()
# Out:
# class
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: count, dtype: int64
